# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/HKF/python classes/Dataset/DataSet/house pricing delhi- MagicBricks.csv")

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# ...

# %%
df.drop('Locality',axis=1,inplace=True)

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  Parking  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi      1.0
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi      1.0
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi      2.0
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi      2.0
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi      2.0
# ...      ...  ...       ...          ...          ...            ...      ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi      1.0
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi      1.0
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi      1.0
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi      1.0
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi      1.0
#
# ...

# %%
# Group by Method is a method that is used for Aggrigations.

df.groupby('Furnishing')['Price'].sum()
# Out:
# Furnishing
# Furnished          3022160000
# Semi-Furnished    14896050000
# Unfurnished        7331750000
# Name: Price, dtype: int64

# %%
# There are some of the methods that we can use with Gropuby
# Sum, Count, value_counts, mean, median, mode.

df.groupby('Furnishing')['Price'].mean()
# Out:
# Furnishing
# Furnished         1.717136e+07
# Semi-Furnished    2.200303e+07
# Unfurnished       2.030956e+07
# Name: Price, dtype: float64

# %%
# We can use more than one column by which we want to aggrigate another column.

df.groupby(['District','Location','Furnishing'])['Price'].mean()
# Out:
# District       Location        Furnishing
# Central Delhi  Karol Bagh      Furnished         1.870000e+07
#                                Semi-Furnished    1.997579e+07
#                                Unfurnished       2.785000e+07
# East Delhi     Dilshad Garden  Furnished         9.680000e+06
#                                Semi-Furnished    8.613000e+06
#                                                      ...
# West Delhi     Punjabi Bagh    Semi-Furnished    3.282222e+07
#                                Unfurnished       2.941111e+07
#                Uttam Nagar     Furnished         4.370000e+06
#                                Semi-Furnished    3.354000e+06
#                                Unfurnished       3.366667e+06
# Name: Price, Length: 102, dtype: float64

# %%
# Data Manipulation with Pandas 


# Data Sorting (Ascending and Descending Order).

# Sort Data According to Price.

df.sort_values(by='Price') # by Default Sort-values will work on ascending order.
# Out:
#            Area  BHK  Bathroom      Furnishing        Location  \
# 47     198.0000    1       1.0       Furnished          Narela
# 918   4900.0000    1       1.0     Unfurnished          Narela
# 912   2077.4327    1       1.0     Unfurnished          Narela
# 1063   405.0000    1       1.0     Unfurnished        Mehrauli
# 260    270.0000    2       1.0  Semi-Furnished      Budh Vihar
# ...         ...  ...       ...             ...             ...
# 440   6000.0000    5       5.0  Semi-Furnished       Hauz Khas
# 1052  6500.0000    4       5.0     Unfurnished       Hauz Khas
# 513   6000.0000    5       5.0  Semi-Furnished  Friends Colony
# 472   8000.0000    4       5.0  Semi-Furnished    Lajpat Nagar
# 473   8000.0000    4       5.0  Semi-Furnished    Lajpat Nagar
#
#               District  Parking         Status   Transaction           Type  \
# 47    North West Delhi      1.0  Ready_to_move        Resale      Apartment
# ...

# %%
# Sort Values in Descending Order

df.sort_values(by='Price',ascending=False)
# Out:
#            Area  BHK  Bathroom      Furnishing        Location  \
# 472   8000.0000    4       5.0  Semi-Furnished    Lajpat Nagar
# 473   8000.0000    4       5.0  Semi-Furnished    Lajpat Nagar
# 513   6000.0000    5       5.0  Semi-Furnished  Friends Colony
# 1052  6500.0000    4       5.0     Unfurnished       Hauz Khas
# 440   6000.0000    5       5.0  Semi-Furnished       Hauz Khas
# ...         ...  ...       ...             ...             ...
# 260    270.0000    2       1.0  Semi-Furnished      Budh Vihar
# 1063   405.0000    1       1.0     Unfurnished        Mehrauli
# 47     198.0000    1       1.0       Furnished          Narela
# 918   4900.0000    1       1.0     Unfurnished          Narela
# 912   2077.4327    1       1.0     Unfurnished          Narela
#
#               District  Parking         Status   Transaction           Type  \
# 472        South Delhi      1.0  Ready_to_move  New_Property  Builder_Floor
# ...

# %%
# How to Create a New Column in Current Dataset.
# Thsi method will add a new column in the end.

df['discount_price'] =  df.Price - df.Price * 10/100

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  Parking  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi      1.0
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi      1.0
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi      2.0
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi      2.0
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi      2.0
# ...      ...  ...       ...          ...          ...            ...      ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi      1.0
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi      1.0
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi      1.0
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi      1.0
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi      1.0
#
# ...

# %%
# Pandas Concatination and Pandas merge methods for Data Wrangling.


admin = pd.DataFrame({'Name':['Shipra','Rupal','Rishi','Kaif','Kunal','Anil'],
                     'Age':[22,23,24,25,26,27],
                     'City':['Delhi','Delhi','Delhi','Delhi','Delhi','Delhi']})

# %%
admin
# Out:
#      Name  Age   City
# 0  Shipra   22  Delhi
# 1   Rupal   23  Delhi
# 2   Rishi   24  Delhi
# 3    Kaif   25  Delhi
# 4   Kunal   26  Delhi
# 5    Anil   27  Delhi

# %%
academics = pd.DataFrame({'Marks':[44,65,75,39,77,44],
                     'Grade':['c','b','b','d','a','c']})

# %%
academics
# Out:
#    Marks Grade
# 0     44     c
# 1     65     b
# 2     75     b
# 3     39     d
# 4     77     a
# 5     44     c

# %%
# Concatination

# Concatination will work on any data. (If there is not a matched column cocat still work on that)

# Concat will work on axis 0 by default (Adding Rows)

pd.concat([admin,academics])
# Out:
#      Name   Age   City  Marks Grade
# 0  Shipra  22.0  Delhi    NaN   NaN
# 1   Rupal  23.0  Delhi    NaN   NaN
# 2   Rishi  24.0  Delhi    NaN   NaN
# 3    Kaif  25.0  Delhi    NaN   NaN
# 4   Kunal  26.0  Delhi    NaN   NaN
# 5    Anil  27.0  Delhi    NaN   NaN
# 0     NaN   NaN    NaN   44.0     c
# 1     NaN   NaN    NaN   65.0     b
# 2     NaN   NaN    NaN   75.0     b
# 3     NaN   NaN    NaN   39.0     d
# 4     NaN   NaN    NaN   77.0     a
# 5     NaN   NaN    NaN   44.0     c

# %%
# Axis 1 is used to concat the data according to columns (Vertically)

pd.concat([admin,academics],axis=1)
# Out:
#      Name  Age   City  Marks Grade
# 0  Shipra   22  Delhi     44     c
# 1   Rupal   23  Delhi     65     b
# 2   Rishi   24  Delhi     75     b
# 3    Kaif   25  Delhi     39     d
# 4   Kunal   26  Delhi     77     a
# 5    Anil   27  Delhi     44     c

# %%
admin = pd.DataFrame({'Name':['Shipra','Rupal','Rishi','Kaif','Kunal','Anil'],
                     'Age':[22,23,24,25,26,27],
                     'City':['Delhi','Delhi','Delhi','Delhi','Delhi','Delhi']})

academics = pd.DataFrame({'Marks':[44,65,75,39,77],
                     'Grade':['c','b','b','d','a']})

# %%
pd.concat([admin,academics],axis=1)
# Out:
#      Name  Age   City  Marks Grade
# 0  Shipra   22  Delhi   44.0     c
# 1   Rupal   23  Delhi   65.0     b
# 2   Rishi   24  Delhi   75.0     b
# 3    Kaif   25  Delhi   39.0     d
# 4   Kunal   26  Delhi   77.0     a
# 5    Anil   27  Delhi    NaN   NaN

# %%
# Pandas Merge Method or Function

# Merge will only works if there is any column that was available in both the datasets.

# %%
admin = pd.DataFrame({'Roll_no':[1,2,3,4,5,6],
                      'Name':['Shipra','Rupal','Rishi','Kaif','Kunal','Anil'],
                     'Age':[22,23,24,25,26,27],
                     'City':['Delhi','Delhi','Delhi','Delhi','Delhi','Delhi']})

academics = pd.DataFrame({'Roll_no':[1,2,3,4,5,6],
                          'Marks':[44,65,75,39,77,33],
                     'Grade':['c','b','b','d','a','d']})

# %%
admin
# Out:
#    Roll_no    Name  Age   City
# 0        1  Shipra   22  Delhi
# 1        2   Rupal   23  Delhi
# 2        3   Rishi   24  Delhi
# 3        4    Kaif   25  Delhi
# 4        5   Kunal   26  Delhi
# 5        6    Anil   27  Delhi

# %%
academics
# Out:
#    Roll_no  Marks Grade
# 0        1     44     c
# 1        2     65     b
# 2        3     75     b
# 3        4     39     d
# 4        5     77     a
# 5        6     33     d

# %%
# Now we can merge adin and academics on the basis of Roll_no

pd.merge(admin,academics)
# Out:
#    Roll_no    Name  Age   City  Marks Grade
# 0        1  Shipra   22  Delhi     44     c
# 1        2   Rupal   23  Delhi     65     b
# 2        3   Rishi   24  Delhi     75     b
# 3        4    Kaif   25  Delhi     39     d
# 4        5   Kunal   26  Delhi     77     a
# 5        6    Anil   27  Delhi     33     d

# %%
admin = pd.DataFrame({'Roll_no':[1,2,3,4,5,6],
                      'Name':['Shipra','Rupal','Rishi','Kaif','Kunal','Anil'],
                     'Age':[22,23,24,25,26,27],
                     'City':['Delhi','Delhi','Delhi','Delhi','Delhi','Delhi']})

academics = pd.DataFrame({'Roll_no':[1,2,3,4,7,8],
                          'Marks':[44,65,75,39,77,33],
                     'Grade':['c','b','b','d','a','d']})

# %%
admin
# Out:
#    Roll_no    Name  Age   City
# 0        1  Shipra   22  Delhi
# 1        2   Rupal   23  Delhi
# 2        3   Rishi   24  Delhi
# 3        4    Kaif   25  Delhi
# 4        5   Kunal   26  Delhi
# 5        6    Anil   27  Delhi

# %%
academics
# Out:
#    Roll_no  Marks Grade
# 0        1     44     c
# 1        2     65     b
# 2        3     75     b
# 3        4     39     d
# 4        7     77     a
# 5        8     33     d

# %%
pd.merge(admin,academics)
# Out:
#    Roll_no    Name  Age   City  Marks Grade
# 0        1  Shipra   22  Delhi     44     c
# 1        2   Rupal   23  Delhi     65     b
# 2        3   Rishi   24  Delhi     75     b
# 3        4    Kaif   25  Delhi     39     d

# %%
# How to Include unmatchable data in Merge Method
# By Default pandas Merge method will work on Inner Joins

pd.merge(admin,academics,how='outer')
# Out:
#    Roll_no    Name   Age   City  Marks Grade
# 0        1  Shipra  22.0  Delhi   44.0     c
# 1        2   Rupal  23.0  Delhi   65.0     b
# 2        3   Rishi  24.0  Delhi   75.0     b
# 3        4    Kaif  25.0  Delhi   39.0     d
# 4        5   Kunal  26.0  Delhi    NaN   NaN
# 5        6    Anil  27.0  Delhi    NaN   NaN
# 6        7     NaN   NaN    NaN   77.0     a
# 7        8     NaN   NaN    NaN   33.0     d

# %%
# BHK 
# Parking
# Budget (Start and End)
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# ...

# %%
data = int(input('Enter BHK Here: '))

park = int(input('Enter Parking Here: '))

s_budget = int(input('Enter Statrting Budget Here: '))

e_budget = int(input('Enter Ending Budget Here: '))

df[(df.BHK==data) & (df.Parking==park) & (df.Price>s_budget) & (df.Price<e_budget)]
# Out:
# Enter BHK Here: 3
# Enter Parking Here: 2
# Enter Statrting Budget Here: 10000000
# Enter Ending Budget Here: 25000000
#         Area  BHK  Bathroom   Furnishing      Location       District  \
# 2     1280.0    3       3.0    Furnished    Karol Bagh  Central Delhi
# 6     1135.0    3       3.0    Furnished    Karol Bagh  Central Delhi
# 9     1500.0    3       3.0    Furnished    Vasundhara     East Delhi
# 25    1000.0    3       2.0    Furnished    Vasundhara     East Delhi
# 29     750.0    3       2.0    Furnished         Okhla     East Delhi
# ...      ...  ...       ...          ...           ...            ...
# 1083  1100.0    3       3.0  Unfurnished     Hauz Khas    South Delhi
# 1091  1350.0    3       3.0  Unfurnished  Sheikh Sarai    South Delhi
# 1095  1143.0    3       3.0  Unfurnished  Lajpat Nagar    South Delhi
# 1171  1429.0    3       3.0  Unfurnished    Moti Nagar     West Delhi
# 1197  1440.0    3       3.0  Unfurnished  Punjabi Bagh     West Delhi
#
# ...

# %%
# Understanding the Pattern w.r.t Data.

# Data Duplicates

# How to Check Duplicates. (Data Cleaning)

df.duplicated().sum()
# Out:
# 79

# %%
# We can check for the rwos via data filteration

df[df.duplicated()]
# Out:
#         Area  BHK  Bathroom   Furnishing      Location       District  \
# 4     1135.0    3       3.0    Furnished    Karol Bagh  Central Delhi
# 18     976.0    2       2.0    Furnished         Okhla     East Delhi
# 85    1800.0    3       3.0    Furnished     Alaknanda    South Delhi
# 96    1000.0    2       2.0    Furnished  Lajpat Nagar    South Delhi
# 110   1400.0    3       3.0    Furnished     Alaknanda    South Delhi
# ...      ...  ...       ...          ...           ...            ...
# 1207  3901.0    4       4.0  Unfurnished   Patel Nagar     West Delhi
# 1208  2306.0    3       3.0  Unfurnished   Patel Nagar     West Delhi
# 1209  4688.0    5       4.0  Unfurnished   Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished   Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished   Patel Nagar     West Delhi
#
#       Parking         Status   Transaction       Type  Per_Sqft      Price  \
# ...

# %%
# Check for Duplicated Data Rows

df[95:98]
# Out:
#       Area  BHK  Bathroom Furnishing      Location     District  Parking  \
# 95  1000.0    2       2.0  Furnished  Lajpat Nagar  South Delhi      1.0
# 96  1000.0    2       2.0  Furnished  Lajpat Nagar  South Delhi      1.0
# 97  1700.0    3       3.0  Furnished  Lajpat Nagar  South Delhi      2.0
#
#            Status Transaction           Type  Per_Sqft     Price  \
# 95  Ready_to_move      Resale      Apartment   20000.0  20000000
# 96  Ready_to_move      Resale      Apartment   20000.0  20000000
# 97  Ready_to_move      Resale  Builder_Floor   20000.0  19000000
#
#     discount_price
# 95      18000000.0
# 96      18000000.0
# 97      17100000.0

# %%
# How to remove duplicate values:\

df = df.drop_duplicates()

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  Parking  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi      1.0
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi      1.0
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi      2.0
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi      2.0
# 5     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi      2.0
# ...      ...  ...       ...          ...          ...            ...      ...
# 1203  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi      1.0
# 1204  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi      1.0
# 1205  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi      1.0
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi      1.0
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi      1.0
#
# ...

# %%
df.Price.mean()
# Out:
# 20534828.1938326

# %%
df[df.Location=='Lajpat Nagar']['Price'].mean()
# Out:
# 27995411.76470588

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df.Price,y=df.Area)
# Out:
# <Axes: xlabel='Price', ylabel='Area'>

# %%
df[(df.Price<50000000) & (df.Location=='Lajpat Nagar')]['Price'].median()
# Out:
# 22000000.0

# %%
df.Price.median()
# Out:
# 13500000.0

# %%
df.groupby(['Location','BHK'])['Price'].mean().head(55)
# Out:
# Location           BHK
# Alaknanda          1      3.000000e+06
#                    2      1.541000e+07
#                    3      2.027879e+07
#                    4      2.150000e+07
# Budh Vihar         1      2.500000e+06
#                    2      3.872222e+06
#                    3      3.850000e+06
#                    6      5.550000e+06
# Chhattarpur        1      1.600000e+06
#                    2      3.615385e+06
#                    3      1.449154e+07
#                    4      8.833333e+06
# Chittaranjan Park  2      1.087500e+07
#                    3      2.349474e+07
#                    4      4.950000e+07
# Dilshad Garden     1      3.266667e+06
#                    2      6.355000e+06
#                    3      1.113300e+07
#                    4      1.250000e+07
# Dwarka             1      3.225000e+06
#                    2      5.384615e+06
#                    3      1.320259e+07
#                    4      1.844071e+07
# ...

# %%
df.groupby([df.Location=='Lajpat Nagar','BHK'])['Price'].mean()
# Out:
# Location  BHK
# False     1      2.793978e+06
#           2      8.205265e+06
#           3      1.780807e+07
#           4      4.513141e+07
#           5      9.525263e+07
#           6      3.855000e+07
#           7      2.650000e+07
#           10     1.700000e+07
# True      1      1.196667e+07
#           2      1.321171e+07
#           3      2.795217e+07
#           4      1.160000e+08
# Name: Price, dtype: float64

# %%
df.groupby([df.Location=='Lajpat Nagar','BHK'])['Price'].mean()
# Out:
# Location  BHK
# False     1      2.793978e+06
#           2      8.205265e+06
#           3      1.780807e+07
#           4      4.513141e+07
#           5      9.525263e+07
#           6      3.855000e+07
#           7      2.650000e+07
#           10     1.700000e+07
# True      1      1.196667e+07
#           2      1.321171e+07
#           3      2.795217e+07
#           4      1.160000e+08
# Name: Price, dtype: float64

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# ...

# %%
df.describe()
# Out:
#                Area          BHK     Bathroom      Parking       Per_Sqft  \
# count   1214.000000  1214.000000  1212.000000  1182.000000     973.000000
# mean    1451.850751     2.778418     2.523927     1.708122   15574.885920
# std     1586.472855     0.946811     1.017723     5.717177   21574.389007
# min       28.000000     1.000000     1.000000     1.000000    1259.000000
# 25%      800.000000     2.000000     2.000000     1.000000    6154.000000
# 50%     1150.000000     3.000000     2.000000     1.000000   10838.000000
# 75%     1620.000000     3.000000     3.000000     2.000000   17647.000000
# max    24300.000000    10.000000     7.000000   114.000000  183333.000000
#
#               Price
# count  1.214000e+03
# mean   2.079898e+07
# std    2.561308e+07
# min    1.000000e+06
# 25%    5.600000e+06
# 50%    1.400000e+07
# 75%    2.500000e+07
# max    2.400000e+08

# %%
df.Area.quantile([0.25,0.50,0.75])
# Out:
# 0.25     800.0
# 0.50    1150.0
# 0.75    1620.0
# Name: Area, dtype: float64

# %%
Q1=800
Q2=1150
Q3=1620

# %%
IQR=Q3-Q1
IQR
# Out:
# 820

# %%
#upper limit and lower limit formulas.
UL=Q3+1.5*(IQR)
LL=Q1-1.5*(IQR)

# %%
UL,LL
# Out:
# (2850.0, -430.0)

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(df.Area,orient='h')
plt.show()

# %%
df.Area=np.where(df.Area>UL,UL,df.Area)

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  2850.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  2850.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# ...

# %%
df.Price.corr(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.Price.corr(df)
#
# File K:\anaconda python\Lib\site-packages\pandas\core\series.py:2860, in Series.corr(self, other, method, min_periods)
#    2857     return np.nan
#    2859 this_values = this.to_numpy(dtype=float, na_value=np.nan, copy=False)
# -> 2860 other_values = other.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2862 if method in ["pearson", "spearman", "kendall"] or callable(method):
#    2863     return nanops.nancorr(
#    2864         this_values, other_values, method=method, min_periods=min_periods
#    2865     )
#
# File K:\anaconda python\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# ...
